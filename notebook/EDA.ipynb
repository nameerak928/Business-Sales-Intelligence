# %%
import pandas as pd

df = pd.read_csv('../Data/Raw data/Sample - Superstore.csv', encoding='latin1')
print(df.shape)
print(df.columns.tolist())

# %%
import pandas as pd

df = pd.read_csv('../Data/Raw data/Sample - Superstore.csv', encoding='latin1')
print(df.shape)
print(df.columns.tolist())
